# %%
import pandas as pd

# %%
df = pd.read_csv("data/nutrition.csv")

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df.sample(1)
# Out:
#                                                    name serving_size  \
# 4566  USDA Commodity Chicken, drained, meat only, ca...        100 g
#
#       calories total_fat saturated_fat cholesterol     sodium  choline  \
# 4566       162      5.7g          1.6g        83mg  271.00 mg  73.8 mg
#
#         folate folic_acid  ...     fat saturated_fatty_acids  \
# 4566  6.00 mcg   0.00 mcg  ...  5.72 g               1.572 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 4566                     2.047 g                     1.313 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 4566                83.00 mg   0.0 g  0.89 g  0.00 mg     0.00 mg  67.29 g
#
# [1 rows x 76 columns]

# %%
df.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
df.describe()
# Out:
#           calories  lucopene
# count  8789.000000    8789.0
# mean    226.283878       0.0
# std     169.862001       0.0
# min       0.000000       0.0
# 25%      91.000000       0.0
# 50%     191.000000       0.0
# 75%     337.000000       0.0
# max     902.000000       0.0

# %% [markdown]
# Lucopene looks like an unecessary variable

# %%
df['lucopene'].unique()
# Out:
# array([0])

# %% [markdown]
# Since the only value is 0 we remove the data

# %%
df = df.drop('lucopene', axis=1)

# %% [markdown]
# The serving size are all the same

# %%
df['serving_size'].unique()
# Out:
# array(['100 g'], dtype=object)

# %%
df['serving_size'] = 100

# %% [markdown]
# ## Transforming g to numerical values

# %%
import re

# %%
def transform(rows):
    return float(re.search("[0-9.]*", rows)[0])

# %%
df['carbohydrate'] = df["carbohydrate"].apply(transform)
df['protein'] = df["protein"].apply(transform)
df['total_fat'] = df["total_fat"].apply(transform)

# %%
df.describe()
# Out:
#        serving_size     calories    total_fat      protein  carbohydrate
# count        8789.0  8789.000000  8789.000000  8789.000000   8789.000000
# mean          100.0   226.283878    10.556855    11.345616     22.121915
# std             0.0   169.862001    15.818247    10.530602     27.266261
# min           100.0     0.000000     0.000000     0.000000      0.000000
# 25%           100.0    91.000000     1.000000     2.380000      0.050000
# 50%           100.0   191.000000     5.100000     8.020000      9.340000
# 75%           100.0   337.000000    14.000000    19.880000     34.910000
# max           100.0   902.000000   100.000000    88.320000    100.000000

# %%
macros_df = df[['name', 'calories', 'protein', 'carbohydrate', 'total_fat']]

# %% [markdown]
# ## Optimization

# %% [markdown]
# 1. Minimize calories
# 2. half of the calories must be carbohydrates, 1g per kg for protein and the rest fat.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pulp import * 
import seaborn as sns

# %%
print(macros_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8789 non-null   object
#  1   calories      8789 non-null   int64
#  2   protein       8789 non-null   float64
#  3   carbohydrate  8789 non-null   float64
#  4   total_fat     8789 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 343.4+ KB
# None

# %%
macros_df.to_csv('macro_nutrients.csv')

# %%
week_days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
split_values = np.linspace(0,len(macros_df),8).astype(int)
split_values[-1] = split_values[-1]-1
def random_dataset():
    frac_data = macros_df.sample(frac=1).reset_index().drop('index',axis=1)
    day_data = []
    for s in range(len(split_values)-1):
        day_data.append(frac_data.loc[split_values[s]:split_values[s+1]])
    return dict(zip(week_days,day_data))

# %%
random_dataset()['Monday']
# Out:
#                                                    name  calories  protein  \
# 0             Blueberries, drained, light syrup, canned        88     1.04
# 1     Beef, raw, Aust. marble score 4/5, separable l...       234    20.35
# 2     Pork, roasted, heated, separable lean only, bo...       139    26.49
# 3                                    Gravy, dry, au jus       313     9.20
# 4                       Soymilk (All flavors), enhanced        45     2.94
# ...                                                 ...       ...      ...
# 1251  Soup, prepared with equal volume milk, canned,...        55     2.51
# 1252  Lamb, fast roasted, cooked, separable lean and...       157    28.96
# 1253  Pork, unheated, separable lean and fat, blade ...       269    16.47
# 1254               Soup, with water, low sodium, tomato        30     0.79
# 1255          Rice, unenriched, raw, short-grain, white       358     6.50
#
#       carbohydrate  total_fat
# 0            22.66        0.4
# 1             0.00       17.0
# 2             0.68        3.7
# 3            47.49        9.6
# 4             3.45        2.0
# ...            ...        ...
# 1251          3.99        3.2
# 1252          0.00        4.6
# 1253          0.00       22.0
# 1254          6.57        0.3
# 1255         79.15        0.5
#
# [1256 rows x 5 columns]

# %%
def build_nutritional_values(kg,calories):
    protein_calories = kg*4
    res_calories = calories-protein_calories
    carb_calories = calories/2.
    fat_calories = calories-carb_calories-protein_calories
    res = {'Protein Calories':protein_calories,'Carbohydrates Calories':carb_calories,'Fat Calories':fat_calories}
    return res

# %%
def extract_gram(table):
    protein_grams = table['Protein Calories']/4.
    carbs_grams = table['Carbohydrates Calories']/4.
    fat_grams = table['Fat Calories']/9.
    res = {'Protein Grams':protein_grams, 'Carbohydrates Grams':carbs_grams,'Fat Grams':fat_grams}
    return res

# %%
print(build_nutritional_values(70,2000))
# Out:
# {'Protein Calories': 280, 'Carbohydrates Calories': 1000.0, 'Fat Calories': 720.0}

# %%
print(extract_gram(build_nutritional_values(70,2000)))
# Out:
# {'Protein Grams': 70.0, 'Carbohydrates Grams': 250.0, 'Fat Grams': 80.0}

# %%
days_data = random_dataset()
def model(day,kg,calories):
    G = extract_gram(build_nutritional_values(kg,calories))
    E = G['Carbohydrates Grams']
    F = G['Fat Grams']
    P = G['Protein Grams']
    day_data = days_data[day]
    day_data = day_data[day_data.calories!=0]
    food = day_data.name.tolist()
    c  = day_data.calories.tolist()
    x  = pulp.LpVariable.dicts( "x", indices = food, lowBound=0, upBound=1.5, cat='Continuous', indexStart=[] )
    e = day_data.carbohydrate.tolist()
    f = day_data.total_fat.tolist()
    p = day_data.protein.tolist()
    prob  = pulp.LpProblem( "Diet", LpMinimize )
    prob += pulp.lpSum( [x[food[i]]*c[i] for i in range(len(food))]  )
    prob += pulp.lpSum( [x[food[i]]*e[i] for i in range(len(x)) ] )>=E
    prob += pulp.lpSum( [x[food[i]]*f[i] for i in range(len(x)) ] )>=F
    prob += pulp.lpSum( [x[food[i]]*p[i] for i in range(len(x)) ] )>=P
    prob.solve()
    variables = []
    values = []
    for v in prob.variables():
        variable = v.name
        value = v.varValue
        variables.append(variable)
        values.append(value)
    values = np.array(values).round(2).astype(float)
    sol = pd.DataFrame(np.array([food,values]).T, columns = ['Food','Quantity'])
    sol['Quantity'] = sol.Quantity.astype(float)
    return sol

# %%
sol_monday = model('Monday',70,1500)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/11d6ff6506ea48929f6a9c8533406772-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/11d6ff6506ea48929f6a9c8533406772-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4603 RHS
# At line 4607 BOUNDS
# At line 5858 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3344 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1228 (-22) columns and 3298 (-46) elements
# 0  Obj 0 Primal inf 3.4271622 (3)
# 10  Obj 1112.0513
# Optimal - objective value 1112.0513
# After Postsolve, objective 1112.0513, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1112.051338 - 10 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
sol_monday = sol_monday[sol_monday['Quantity']!=0.0]
sol_monday.Quantity = sol_monday.Quantity*100
sol_monday = sol_monday.rename(columns={'Quantity':'Quantity (g)'})
sol_monday
# Out:
#                                                    Food  Quantity (g)
# 70        Chicken, simmered, cooked, all classes, heart         150.0
# 71    Lamb, roasted, cooked, trimmed to 1/8" fat, se...         150.0
# 359            WORTHINGTON Choplets, unprepared, canned         150.0
# 609      Fish, dry heat, cooked, fresh, yellowfin, tuna          62.0
# 1137  Beverages, with vitamin E added, reduced sugar...         144.0
# 1139  Beef, raw, choice, trimmed to 1/8" fat, separa...         150.0
# 1165  Cereals, cinnamon, weight control, Instant Oat...          33.0

# %%
def model(prob,day,kg,calories):
    G = extract_gram(build_nutritional_values(kg,calories))
    E = G['Carbohydrates Grams']
    F = G['Fat Grams']
    P = G['Protein Grams']
    day_data = days_data[day]
    day_data = day_data[day_data.calories!=0]
    food = day_data.name.tolist()
    c  = day_data.calories.tolist()
    x  = pulp.LpVariable.dicts( "x", indices = food, lowBound=0, upBound=1.5, cat='Continuous', indexStart=[] )
    e = day_data.carbohydrate.tolist()
    f = day_data.total_fat.tolist()
    p = day_data.protein.tolist()
#    prob  = pulp.LpProblem( "Diet", LpMinimize )
    prob += pulp.lpSum( [x[food[i]]*c[i] for i in range(len(food))]  )
    prob += pulp.lpSum( [x[food[i]]*e[i] for i in range(len(x)) ] )>=E
    prob += pulp.lpSum( [x[food[i]]*f[i] for i in range(len(x)) ] )>=F
    prob += pulp.lpSum( [x[food[i]]*p[i] for i in range(len(x)) ] )>=P
    prob.solve()
    variables = []
    values = []
    for v in prob.variables():
        variable = v.name
        value = v.varValue
        variables.append(variable)
        values.append(value)
    values = np.array(values).round(2).astype(float)
    sol = pd.DataFrame(np.array([food,values]).T, columns = ['Food','Quantity'])
    sol['Quantity'] = sol.Quantity.astype(float)
    sol = sol[sol['Quantity']!=0.0]
    sol.Quantity = sol.Quantity*100
    sol = sol.rename(columns={'Quantity':'Quantity (g)'})
    return sol
def total_model(kg,calories):
    result = []
    for day in week_days:
        prob  = pulp.LpProblem( "Diet", LpMinimize )
        print('Building a model for day %s \n'%(day))
        result.append(model(prob,day,kg,calories))
    return dict(zip(week_days,result))

# %%
diet = total_model(70,3000)
# Out:
# Building a model for day Monday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f7a25d1548a04e708f8f6b3f62964c97-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/f7a25d1548a04e708f8f6b3f62964c97-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4603 RHS
# At line 4607 BOUNDS
# At line 5858 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3344 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1228 (-22) columns and 3298 (-46) elements
# 0  Obj 0 Primal inf 6.2694959 (3)
# 6  Obj 2353.6678
# Optimal - objective value 2353.6678
# After Postsolve, objective 2353.6678, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2353.667828 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Tuesday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/685a32ac31bd410e88f446ebd5f2d419-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/685a32ac31bd410e88f446ebd5f2d419-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4585 RHS
# At line 4589 BOUNDS
# At line 5840 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3326 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1231 (-19) columns and 3292 (-34) elements
# 0  Obj 0 Primal inf 5.9383009 (3)
# 5  Obj 2130.7416
# Optimal - objective value 2130.7416
# After Postsolve, objective 2130.7416, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2130.741578 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Wednesday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/75878442ae1e4d6ebacfff6ccb92a8ab-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/75878442ae1e4d6ebacfff6ccb92a8ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4602 RHS
# At line 4606 BOUNDS
# At line 5857 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3343 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1219 (-31) columns and 3291 (-52) elements
# 0  Obj 0 Primal inf 357.24517 (3)
# 5  Obj 2078.7609
# Optimal - objective value 2078.7609
# After Postsolve, objective 2078.7609, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2078.760897 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Thursday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/aca65b9f98264baf940fff902c663278-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/aca65b9f98264baf940fff902c663278-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4605 RHS
# At line 4609 BOUNDS
# At line 5861 ENDATA
# Problem MODEL has 3 rows, 1251 columns and 3345 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1223 (-28) columns and 3288 (-57) elements
# 0  Obj 0 Primal inf 5.9533001 (3)
# 7  Obj 2163.6621
# Optimal - objective value 2163.6621
# After Postsolve, objective 2163.6621, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2163.662077 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Friday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a3ba5f6b17e845d38fcc8dc15a2945aa-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/a3ba5f6b17e845d38fcc8dc15a2945aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4602 RHS
# At line 4606 BOUNDS
# At line 5857 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3343 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1226 (-24) columns and 3299 (-44) elements
# 0  Obj 0 Primal inf 5.9233096 (3)
# 5  Obj 2264.5071
# Optimal - objective value 2264.5071
# After Postsolve, objective 2264.5071, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2264.507146 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Saturday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f87ff1a779554b07b7b4f98133595d5a-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/f87ff1a779554b07b7b4f98133595d5a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4628 RHS
# At line 4632 BOUNDS
# At line 5886 ENDATA
# Problem MODEL has 3 rows, 1253 columns and 3366 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1235 (-18) columns and 3331 (-35) elements
# 0  Obj 0 Primal inf 457.19999 (3)
# 5  Obj 2126.8768
# Optimal - objective value 2126.8768
# After Postsolve, objective 2126.8768, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2126.876849 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Sunday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/57f71c0201284e5383819991488ac3da-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/57f71c0201284e5383819991488ac3da-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4598 RHS
# At line 4602 BOUNDS
# At line 5855 ENDATA
# Problem MODEL has 3 rows, 1252 columns and 3337 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1226 (-26) columns and 3278 (-59) elements
# 0  Obj 0 Primal inf 5.9761995 (3)
# 5  Obj 2063.8172
# Optimal - objective value 2063.8172
# After Postsolve, objective 2063.8172, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2063.817233 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
diet
# Out:
# {'Monday':                                                    Food  Quantity (g)
#  235   Beef, braised, cooked, all grades, trimmed to ...         150.0
#  298   Pie crust, chilled, vanilla wafer, prepared fr...         122.0
#  359            WORTHINGTON Choplets, unprepared, canned         150.0
#  409              Ice creams, soft-serve, light, vanilla          49.0
#  756   Cereals ready-to-eat, SPECIAL K Protein Plus, ...         150.0
#  761   Soy sauce, made from hydrolyzed vegetable prot...         150.0
#  839              Frozen novelties, fruit and juice bars          79.0
#  913   Soup, prepared with equal volume water, canned...         150.0
#  1137  Beverages, with vitamin E added, reduced sugar...         150.0
#  1138            Cheesefurter, beef, pork, cheese smokie         150.0
#  1139  Beef, raw, choice, trimmed to 1/8" fat, separa...         150.0
#  1170  Lima beans, without salt, boiled, cooked, matu...         150.0,
#  'Tuesday':                                                    Food  Quantity (g)
#  380   Succotash, solids and liquids, with whole kern...          10.0
#  456               McDONALD'S, Grilled, RANCH SNACK WRAP         150.0
#  585   Snacks, all flavors, QUAKER OATMEAL TO GO, gra...         150.0
#  739   Beef, raw, select, trimmed to 1/8" fat, separa...         150.0
#  774   Beef, roasted, cooked, choice, trimmed to 1/8"...         150.0
#  781   Formulated bar, SNICKERS MARATHON MULTIGRAIN C...         150.0
#  828   Beef, raw, Aust. marble score 4/5, separable l...         118.0
#  1041  KEEBLER, soft, Oatmeal Raisin Cookie, BAKER'S ...          33.0
#  1149                                             Wasabi         150.0,
#  'Wednesday':                                                    Food  Quantity (g)
#  75        Babyfood, junior, vegetables and beef, dinner         150.0
#  230            Lamb, raw, brains, imported, New Zealand         150.0
#  231   Buffalo, raw (Shoshone Bannock), top round ste...         150.0
#  378   Fruit cocktail, solids and liquids, heavy syru...         150.0
#  458   Artichokes, without salt, drained, boiled, coo...          92.0
#  465                 Cheese, nonfat or fat free, cheddar         150.0
#  775                             Picnic loaf, beef, pork         150.0
#  1123     Nuts, without salt added, plain, almond butter          14.0
#  1126  Infant formula, ready-to-feed, ADVANCE with ir...         150.0,
#  'Thursday':                                                    Food  Quantity (g)
#  367   Cereals ready-to-eat, Honey Nut SCOOTERS, MALT...         150.0
#  373   Infant formula, with ARA and DHA, powder, NEOS...          41.0
#  583   Beef, pan-browned, cooked, crumbles, 95% lean ...         150.0
#  780   Veal, cooked, separable fat, composite of trim...         149.0
#  821   Potatoes, oven-heated, frozen, salt added in p...         150.0
#  828                Frozen novelties, orange, juice type         150.0
#  1061  Potatoes, unprepared, with butter sauce, froze...         116.0
#  1120                  T.G.I. FRIDAY'S, fried mozzarella         150.0,
#  'Friday':                                                    Food  Quantity (g)
#  62    CAMPBELL'S, condensed, 98% Fat Free Cream of C...         150.0
#  80    Soup, prepared with equal volume water, canned...          32.0
#  238                    Pears, uncooked, sulfured, dried         150.0
#  360   Beef, grilled, cooked, all grades, trimmed to ...         112.0
#  470   Cereals ready-to-eat, HONEY GRAHAM SQUARES, MA...         150.0
#  726   Beef, raw, Aust. marble score 9, separable lea...         150.0
#  763   Milk, vitamin A and vitamin D, with added nonf...          93.0
#  1009  Babyfood, dry, with apple and orange, high pro...         150.0
#  1127  Veal, braised, cooked, separable lean and fat,...         150.0,
#  'Saturday':                                                    Food  Quantity (g)
#  250                               McDONALD'S, Hamburger         150.0
#  262     Plums, with added sugar, stewed, dried (prunes)         150.0
#  267                     Soymilk (All flavors), enhanced         150.0
#  478   Soymilk, vitamins A and D, with added calcium,...         150.0
#  753   Squash, with salt, baked, cooked, butternut, w...         150.0
#  769   Cowpeas, without salt, drained, boiled, cooked...          39.0
#  783   CAMPBELL'S Soup on the GO, HEALTHY REQUEST Chi...         134.0
#  1058                              SILK Plain soy yogurt         150.0
#  1144  Pan Dulce, contains wheat flour and rice flour...          43.0
#  1239  Lamb, raw, trimmed to 1/8" fat, separable lean...         150.0,
#  'Sunday':                                                    Food  Quantity (g)
#  31                            PACE, Diced Green Chilies         150.0
#  277                   Yardlong beans, raw, mature seeds         150.0
#  346   Cereals ready-to-eat, KELLOGG'S COCOA KRISPIES...         150.0
#  381                MURRAY, Lemon Creme Sandwich Cookies         150.0
#  474   Potatoes, dry form, granules without milk, deh...         150.0
#  669           Pie, commercially prepared, coconut creme          31.0
#  762   Chicken, raw, meat and skin, breast, broilers ...         150.0
#  850                         Soybeans, raw, mature seeds         150.0
#  859     Goose, roasted, cooked, meat only, domesticated         120.0
#  1134      Pears, solids and liquids, juice pack, canned          71.0}
