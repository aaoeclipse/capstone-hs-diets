# %%
import pandas as pd

# %%
df = pd.read_csv("data/nutrition.csv")

# %%
df = df.drop(columns="Unnamed: 0")

# %%
df.sample(1)
# Out:
#                                                    name serving_size  \
# 6636  Rice, cooked without salt, unenriched, regular...        100 g
#
#       calories total_fat saturated_fat cholesterol   sodium choline    folate  \
# 6636       130      0.3g          0.1g           0  1.00 mg  2.1 mg  3.00 mcg
#
#      folic_acid  ...     fat saturated_fatty_acids  \
# 6636   0.00 mcg  ...  0.28 g               0.077 g
#
#      monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 6636                     0.088 g                     0.076 g
#
#      fatty_acids_total_trans alcohol     ash caffeine theobromine    water
# 6636                 0.00 mg   0.0 g  0.41 g  0.00 mg     0.00 mg  68.44 g
#
# [1 rows x 76 columns]

# %%
df.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
df.describe()
# Out:
#           calories  lucopene
# count  8789.000000    8789.0
# mean    226.283878       0.0
# std     169.862001       0.0
# min       0.000000       0.0
# 25%      91.000000       0.0
# 50%     191.000000       0.0
# 75%     337.000000       0.0
# max     902.000000       0.0

# %% [markdown]
# Lucopene looks like an unecessary variable

# %%
df['lucopene'].unique()
# Out:
# array([0])

# %% [markdown]
# Since the only value is 0 we remove the data

# %%
df = df.drop('lucopene', axis=1)

# %% [markdown]
# The serving size are all the same

# %%
df['serving_size'].unique()
# Out:
# array(['100 g'], dtype=object)

# %%
df['serving_size'] = 100

# %% [markdown]
# ## Transforming g to numerical values

# %%
import re

# %%
def transform(rows):
    return float(re.search("[0-9.]*", rows)[0])

# %%
df['carbohydrate'] = df["carbohydrate"].apply(transform)
df['protein'] = df["protein"].apply(transform)
df['total_fat'] = df["total_fat"].apply(transform)

# %%
df.describe()
# Out:
#        serving_size     calories    total_fat      protein  carbohydrate
# count        8789.0  8789.000000  8789.000000  8789.000000   8789.000000
# mean          100.0   226.283878    10.556855    11.345616     22.121915
# std             0.0   169.862001    15.818247    10.530602     27.266261
# min           100.0     0.000000     0.000000     0.000000      0.000000
# 25%           100.0    91.000000     1.000000     2.380000      0.050000
# 50%           100.0   191.000000     5.100000     8.020000      9.340000
# 75%           100.0   337.000000    14.000000    19.880000     34.910000
# max           100.0   902.000000   100.000000    88.320000    100.000000

# %%
macros_df = df[['name', 'calories', 'protein', 'carbohydrate', 'total_fat']]

# %% [markdown]
# ## Optimization

# %% [markdown]
# 1. Minimize calories
# 2. half of the calories must be carbohydrates, 1g per kg for protein and the rest fat.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
from pulp import * 
import seaborn as sns

# %%
print(macros_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8789 non-null   object
#  1   calories      8789 non-null   int64
#  2   protein       8789 non-null   float64
#  3   carbohydrate  8789 non-null   float64
#  4   total_fat     8789 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 343.4+ KB
# None

# %%
week_days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
split_values = np.linspace(0,len(macros_df),8).astype(int)
split_values[-1] = split_values[-1]-1
def random_dataset():
    frac_data = macros_df.sample(frac=1).reset_index().drop('index',axis=1)
    day_data = []
    for s in range(len(split_values)-1):
        day_data.append(frac_data.loc[split_values[s]:split_values[s+1]])
    return dict(zip(week_days,day_data))

# %%
random_dataset()['Monday']
# Out:
#                                                    name  calories  protein  \
# 0     Chicken, not reheated, frozen, precooked, dark...       260    12.43
# 1                         Crackers, whole grain, cheese       412     9.62
# 2               Cookies, chocolate-covered, sugar wafer       526     3.45
# 3                                       Fish, raw, carp       127    17.83
# 4     Beans, unprepared, all styles, frozen, green, ...        39     1.79
# ...                                                 ...       ...      ...
# 1251  PIZZA HUT 14" Pepperoni Pizza, THIN 'N CRISPY ...       333    14.13
# 1252  Pork, broiled, cooked, boneless, separable lea...       169    26.14
# 1253                Peppers, freeze-dried, green, sweet       314    17.90
# 1254   Crustaceans, home recipe, crab cakes, blue, crab       155    20.21
# 1255           Beverages, sugar free, AMP, Energy drink         2     0.00
#
#       carbohydrate  total_fat
# 0            16.32       16.0
# 1            57.29       16.0
# 2            65.99       28.0
# 3             0.00        5.6
# 4             7.54        0.2
# ...            ...        ...
# 1251         32.66       16.0
# 1252          0.89        6.7
# 1253         68.70        3.0
# 1254          0.48        7.5
# 1255          1.03        0.0
#
# [1256 rows x 5 columns]

# %%
def build_nutritional_values(kg,calories):
    protein_calories = kg*4
    res_calories = calories-protein_calories
    carb_calories = calories/2.
    fat_calories = calories-carb_calories-protein_calories
    res = {'Protein Calories':protein_calories,'Carbohydrates Calories':carb_calories,'Fat Calories':fat_calories}
    return res

# %%
def extract_gram(table):
    protein_grams = table['Protein Calories']/4.
    carbs_grams = table['Carbohydrates Calories']/4.
    fat_grams = table['Fat Calories']/9.
    res = {'Protein Grams':protein_grams, 'Carbohydrates Grams':carbs_grams,'Fat Grams':fat_grams}
    return res

# %%
print(build_nutritional_values(70,2000))
# Out:
# {'Protein Calories': 280, 'Carbohydrates Calories': 1000.0, 'Fat Calories': 720.0}

# %%
print(extract_gram(build_nutritional_values(70,2000)))
# Out:
# {'Protein Grams': 70.0, 'Carbohydrates Grams': 250.0, 'Fat Grams': 80.0}

# %%
days_data = random_dataset()
def model(day,kg,calories):
    G = extract_gram(build_nutritional_values(kg,calories))
    E = G['Carbohydrates Grams']
    F = G['Fat Grams']
    P = G['Protein Grams']
    day_data = days_data[day]
    day_data = day_data[day_data.calories!=0]
    food = day_data.name.tolist()
    c  = day_data.calories.tolist()
    x  = pulp.LpVariable.dicts( "x", indices = food, lowBound=0, upBound=1.5, cat='Continuous', indexStart=[] )
    e = day_data.carbohydrate.tolist()
    f = day_data.total_fat.tolist()
    p = day_data.protein.tolist()
    prob  = pulp.LpProblem( "Diet", LpMinimize )
    prob += pulp.lpSum( [x[food[i]]*c[i] for i in range(len(food))]  )
    prob += pulp.lpSum( [x[food[i]]*e[i] for i in range(len(x)) ] )>=E
    prob += pulp.lpSum( [x[food[i]]*f[i] for i in range(len(x)) ] )>=F
    prob += pulp.lpSum( [x[food[i]]*p[i] for i in range(len(x)) ] )>=P
    prob.solve()
    variables = []
    values = []
    for v in prob.variables():
        variable = v.name
        value = v.varValue
        variables.append(variable)
        values.append(value)
    values = np.array(values).round(2).astype(float)
    sol = pd.DataFrame(np.array([food,values]).T, columns = ['Food','Quantity'])
    sol['Quantity'] = sol.Quantity.astype(float)
    return sol

# %%
sol_monday = model('Monday',70,1500)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8f90078f7f87456cb0c17c52af005a43-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8f90078f7f87456cb0c17c52af005a43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4580 RHS
# At line 4584 BOUNDS
# At line 5834 ENDATA
# Problem MODEL has 3 rows, 1249 columns and 3322 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1226 (-23) columns and 3273 (-49) elements
# 0  Obj 0 Primal inf 3.2563824 (3)
# 7  Obj 1045.8653
# Optimal - objective value 1045.8653
# After Postsolve, objective 1045.8653, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1045.865294 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
sol_monday = sol_monday[sol_monday['Quantity']!=0.0]
sol_monday.Quantity = sol_monday.Quantity*100
sol_monday = sol_monday.rename(columns={'Quantity':'Quantity (g)'})
sol_monday
# Out:
#                                                    Food  Quantity (g)
# 20    Beef, braised, cooked, all grades, trimmed to ...         150.0
# 74    Beans, rinsed in tap water, drained solids, ca...         125.0
# 100          KASHI Black Bean Mango, unprepared, frozen         150.0
# 575          Potatoes, with salt, flesh and skin, baked          88.0
# 732                 Beans, no salt added, canned, baked         150.0
# 936   Infant formula, 20 calories ready-to-feed Low ...          72.0
# 1132  Cake, prepared from recipe without frosting, c...         150.0
# 1227  Lamb, raw, choice, trimmed to 1/4" fat, separa...         150.0

# %%
def model(prob,day,kg,calories):
    G = extract_gram(build_nutritional_values(kg,calories))
    E = G['Carbohydrates Grams']
    F = G['Fat Grams']
    P = G['Protein Grams']
    day_data = days_data[day]
    day_data = day_data[day_data.calories!=0]
    food = day_data.name.tolist()
    c  = day_data.calories.tolist()
    x  = pulp.LpVariable.dicts( "x", indices = food, lowBound=0, upBound=1.5, cat='Continuous', indexStart=[] )
    e = day_data.carbohydrate.tolist()
    f = day_data.total_fat.tolist()
    p = day_data.protein.tolist()
#    prob  = pulp.LpProblem( "Diet", LpMinimize )
    prob += pulp.lpSum( [x[food[i]]*c[i] for i in range(len(food))]  )
    prob += pulp.lpSum( [x[food[i]]*e[i] for i in range(len(x)) ] )>=E
    prob += pulp.lpSum( [x[food[i]]*f[i] for i in range(len(x)) ] )>=F
    prob += pulp.lpSum( [x[food[i]]*p[i] for i in range(len(x)) ] )>=P
    prob.solve()
    variables = []
    values = []
    for v in prob.variables():
        variable = v.name
        value = v.varValue
        variables.append(variable)
        values.append(value)
    values = np.array(values).round(2).astype(float)
    sol = pd.DataFrame(np.array([food,values]).T, columns = ['Food','Quantity'])
    sol['Quantity'] = sol.Quantity.astype(float)
    sol = sol[sol['Quantity']!=0.0]
    sol.Quantity = sol.Quantity*100
    sol = sol.rename(columns={'Quantity':'Quantity (g)'})
    return sol
def total_model(kg,calories):
    result = []
    for day in week_days:
        prob  = pulp.LpProblem( "Diet", LpMinimize )
        print('Building a model for day %s \n'%(day))
        result.append(model(prob,day,kg,calories))
    return dict(zip(week_days,result))

# %%
diet = total_model(70,3000)
# Out:
# Building a model for day Monday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2d08879d64504cc49c947db344eac104-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/2d08879d64504cc49c947db344eac104-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4580 RHS
# At line 4584 BOUNDS
# At line 5834 ENDATA
# Problem MODEL has 3 rows, 1249 columns and 3322 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1226 (-23) columns and 3273 (-49) elements
# 0  Obj 0 Primal inf 5.9913384 (3)
# 9  Obj 2224.0194
# Optimal - objective value 2224.0194
# After Postsolve, objective 2224.0194, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2224.019367 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Tuesday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/33eed83f182a4da09912e3b2f0832c21-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/33eed83f182a4da09912e3b2f0832c21-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4613 RHS
# At line 4617 BOUNDS
# At line 5868 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3354 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1225 (-25) columns and 3304 (-50) elements
# 0  Obj 0 Primal inf 6.2881233 (3)
# 2  Obj 1970.9671
# Optimal - objective value 1970.9671
# After Postsolve, objective 1970.9671, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1970.967113 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Wednesday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/50fd1583875e4e60b6cd99194fd3ae05-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/50fd1583875e4e60b6cd99194fd3ae05-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4607 RHS
# At line 4611 BOUNDS
# At line 5862 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3348 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1215 (-35) columns and 3281 (-67) elements
# 0  Obj 0 Primal inf 5.9727753 (3)
# 6  Obj 2246.7653
# Optimal - objective value 2246.7653
# After Postsolve, objective 2246.7653, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2246.765257 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Thursday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/111ce4d6c01748ab95a4e63a20899293-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/111ce4d6c01748ab95a4e63a20899293-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4623 RHS
# At line 4627 BOUNDS
# At line 5882 ENDATA
# Problem MODEL has 3 rows, 1254 columns and 3360 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1233 (-21) columns and 3314 (-46) elements
# 0  Obj 0 Primal inf 5.9611884 (3)
# 6  Obj 2017.5254
# Optimal - objective value 2017.5254
# After Postsolve, objective 2017.5254, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2017.525423 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Friday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e1587ad85af243e395a902480966d200-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/e1587ad85af243e395a902480966d200-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4610 RHS
# At line 4614 BOUNDS
# At line 5868 ENDATA
# Problem MODEL has 3 rows, 1253 columns and 3348 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1227 (-26) columns and 3298 (-50) elements
# 0  Obj 0 Primal inf 5.9870667 (3)
# 9  Obj 2306.7019
# Optimal - objective value 2306.7019
# After Postsolve, objective 2306.7019, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2306.701853 - 9 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Saturday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6ed8b46f383d48158796c352e975b419-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/6ed8b46f383d48158796c352e975b419-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4614 RHS
# At line 4618 BOUNDS
# At line 5869 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3355 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1231 (-19) columns and 3324 (-31) elements
# 0  Obj 0 Primal inf 6.0022454 (3)
# 5  Obj 2253.2062
# Optimal - objective value 2253.2062
# After Postsolve, objective 2253.2062, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2253.206213 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Building a model for day Sunday
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/eclipse/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/91d0198b1d89428287a4f7a35e6428a1-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/91d0198b1d89428287a4f7a35e6428a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 4579 RHS
# At line 4583 BOUNDS
# At line 5834 ENDATA
# Problem MODEL has 3 rows, 1250 columns and 3320 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 1230 (-20) columns and 3287 (-33) elements
# 0  Obj 0 Primal inf 329.01126 (3)
# 6  Obj 2158.2311
# Optimal - objective value 2158.2311
# After Postsolve, objective 2158.2311, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2158.231071 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
diet
# Out:
# {'Monday':                                                    Food  Quantity (g)
#  20    Beef, braised, cooked, all grades, trimmed to ...         150.0
#  74    Beans, rinsed in tap water, drained solids, ca...          19.0
#  100          KASHI Black Bean Mango, unprepared, frozen         150.0
#  389   Puddings, sodium, potassium, with added oil, r...         150.0
#  575          Potatoes, with salt, flesh and skin, baked         150.0
#  732                 Beans, no salt added, canned, baked         150.0
#  733   Yogurt, fortified with vitamin D, sweetened wi...         150.0
#  756               Babyfood, strained, banana no tapioca          16.0
#  815                  Pancakes, dry mix, special dietary         139.0
#  1132  Cake, prepared from recipe without frosting, c...         150.0
#  1227  Lamb, raw, choice, trimmed to 1/4" fat, separa...         150.0,
#  'Tuesday':                                                   Food  Quantity (g)
#  363  Cereals ready-to-eat, STRAWBERRY FIELDS, KASHI...         132.0
#  399  MCKEE BAKING, Chocolate Covered, Wafers with P...         150.0
#  474  Soup, prepared with equal volume low fat (2%) ...         150.0
#  480  KEEBLER, Dark Chocolate, Cheesecake Middles, F...         150.0
#  799         MURRAY, Old Fashioned Iced Oatmeal Cookies          94.0
#  812  Beef, braised, cooked, all grades, separable l...         150.0,
#  'Wednesday':                                                    Food  Quantity (g)
#  245   Beef, braised, cooked, choice, trimmed to 0" f...         150.0
#  364   Pork, raw, separable lean and fat, boneless, c...         150.0
#  752   Luncheon meat, includes SPAM (Hormel), canned,...         150.0
#  753   PREGO Pasta, ready-to-serve, Diced Onion and G...         150.0
#  756   Beef, grilled, cooked, select, trimmed to 1/8"...         150.0
#  853   Lamb, raw, choice, trimmed to 1/4" fat, separa...          82.0
#  1128  Infant formula, powder, PROTECT PLUS, GOOD STA...         150.0
#  1130  CRACKER BARREL, fried, chicken tenderloin platter         150.0
#  1131  KELLOGG'S, Frosted Waffle Cone Toaster Pastrie...          68.0
#  1137             Seeds, partially defatted, sesame meal          36.0,
#  'Thursday':                                                    Food  Quantity (g)
#  70                        APPLEBEE'S, mozzarella sticks         150.0
#  334                              Apples, with skin, raw         150.0
#  447                      Cocoa, unsweetened, dry powder         150.0
#  466                        Beverages, powder, Cocoa mix         150.0
#  683              Nuts, sweetened, canned, coconut cream         125.0
#  843   Bread, toasted (includes whole-grain), multi-g...         150.0
#  848   Oil, filling fat (non-hydrogenated), palm and ...          36.0
#  1142  Beef, cooked, select, trimmed to 1/8" fat, sep...          19.0,
#  'Friday':                                                    Food  Quantity (g)
#  400                               Drumstick leaves, raw         150.0
#  439      CAMPBELL'S CHUNKY Soups, Steak 'N' Potato Soup         141.0
#  753                                   DENNY'S, coleslaw         150.0
#  759   Soup, ready-to-serve, beef broth or bouillon c...         150.0
#  788   Soy protein concentrate, produced by alcohol e...         150.0
#  824              AUSTIN, sandwich-type, PB & J Crackers          85.0
#  1025                               DENNY'S, onion rings         150.0
#  1061                              Durian, raw or frozen         150.0
#  1075               Pork and beef sausage, cooked, fresh          31.0
#  1177  Beef, grilled, cooked, select, trimmed to 0" f...         150.0,
#  'Saturday':                                                    Food  Quantity (g)
#  231                                   Ostrich, raw, fan         150.0
#  239   SUNSHINE, Reduced Fat, 100 Calorie Right Bites...         150.0
#  376   Lamb, raw, trimmed to 1/8" fat, separable lean...         150.0
#  827   Applesauce, without added ascorbic acid (inclu...           3.0
#  992   Apricots, without added sugar, stewed, sulfure...         150.0
#  1052  Pork, unheated, separable lean only, bone-in, ...         150.0
#  1128                               Sour cream, fat free         150.0
#  1134  Beef, raw, select, trimmed to 0" fat, separabl...         150.0
#  1154                                       Cheese, edam          26.0
#  1216                            Spices, dried, tarragon          85.0
#  1229  Restaurant, fried, battered or breaded, fish f...         150.0,
#  'Sunday':                                                    Food  Quantity (g)
#  254                      Onions, tops only, young green          26.0
#  370   MORNINGSTAR FARMS Chik Patties Original, unpre...         150.0
#  733       Vegetables, solids and liquids, canned, mixed         150.0
#  824   Cereals ready-to-eat, Fruity DYNO-BITES, MALT-...         101.0
#  981                              Falafel, home-prepared         150.0
#  1108               WENDY'S, with cheese, CLASSIC DOUBLE           6.0
#  1116                  Mollusks, baked or broiled, conch         150.0
#  1118             Sausage, smoked, pork and beef, Polish         150.0}
